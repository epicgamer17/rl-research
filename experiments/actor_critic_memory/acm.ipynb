# %%
# CONFIG NEEDED : 
# - env
# PPO config above but env : inshape = obs shape + acm output shape, 
# ACM network config - inpud_shape, output_shape, embed shapes, log (bool), optimizer, learning rate, device, num layer
# Memory buffer config - buffer size
# main model config - checkpoint path - training steps, print interval, steps per epoch checkpoint interval

from ppo.ppo_agent import PPOAgent
import gymnasium as gym
import torch
from agent_configs import PPOConfig, ActorConfig, CriticConfig
from ACMconfig import ACModelconfig, ACMNconfig, ACMAconfig, Buffconfig, MHABconfig
from game_configs import CartPoleConfig
from acm_agent import ACMAgent
from acm_network import MHA
env = gym.make('CartPole-v1', render_mode='rgb_array')

device = torch.device('mps')

MultiHeadAttentionBlockconfig = {
    'optimizer': "Adam",
    'learning_rate': 1e-4,
    'adam_epsilon': 1e-7,
    'clipnorm': 0.5,
    'layers': [
        {
            'type': 'MultiheadAttention',
            'num_heads': 1,
            'dropout': 0.1,
            'embed_dim': 1,
            'bias': False,
            'batch_first': True,
            'kdim': 1,
            'vdim': 1,
            'add_zero_attn': False,
            'add_bias_kv': False
        }
    ],
    'self_attention': [
        False,
    ]
}

ACMconfig = {
    'input_shape': 1,
    'output_shape': 1,
    'embed_shapes': [4, 4, 1],
    'log': False,
    'optimizer': "Adam",
    'learning_rate': 1e-3,
    'adam_epsilon': 1e-7,
    'clipnorm': 0.5,
    'device': torch.device('mps'),
    'num_layers': 1
}

MainModelConfig = {
    'checkpoint_path': 'checkpoints/ACMCartPole',
    'training_steps': 100000,
    'print_interval': 1000,
    'steps_per_epoch': 512,
    'checkpoint_interval': 5000,
    'env': env,
    'log': True,
}

MemoryBufferConfig = {
    'buffer_size': 1000,
}
config_dict = {
        'activation': 'tanh',
        'clip_param': 0.2,
        'kernel_initializer': 'orthogonal',
        # NORMALIZATION?
        'discount_factor': 0.99,
        'gae_lambda': 0.95,
        'critic_dense_layers': [64],
        'actor_dense_layers': [64],
        # REWARD CLIPPING
        'steps_per_epoch': 512,
        'train_policy_iterations': 4,
        'train_value_iterations': 4,
        'target_kl': 0.02,
        'entropy_coefficient': 0.01,
        'num_minibatches': 4,
        'loss_function': None,
        'observation_space': None
    }

actor_config_dict = {
    'optimizer': torch.optim.Adam,
    'learning_rate': 2.5e-4,
    'adam_epsilon': 1e-7,
    'clipnorm': 0.5,
    'loss_function': None,
}

critic_config_dict = {
    'optimizer': torch.optim.Adam,
    'learning_rate': 2.5e-4,
    'adam_epsilon': 1e-7,
    'clipnorm': 0.5,
    'loss_function': None,
}

# print("Actor Config")
actor_config = ActorConfig(actor_config_dict)
# print("Critic Config")
critic_config = CriticConfig(critic_config_dict)

# print("PPO Config")
config = PPOConfig(config_dict, CartPoleConfig(), actor_config=actor_config, critic_config=critic_config)

# print("ACM Attention Network Config")
ACMNconfigdict = ACMNconfig(config=ACMconfig)

# print("ACM whole model (attention + ppo) Config")
MainModelConfig = ACMAconfig(MainModelConfig)

# print("Memory Buffer Config (for Attention Network)")
MemoryBufferConfig = Buffconfig(MemoryBufferConfig)



MultiHeadAttentionBlockconfig = MHABconfig(config=MultiHeadAttentionBlockconfig)
MultiHeadAgent = MHA(config=MultiHeadAttentionBlockconfig, device="mps", logging=False)

configurations = {
    'ACMNconfig': ACMNconfigdict,
    'ACMconfig': MainModelConfig,
    'Buff': MemoryBufferConfig,
    'PPOconfig': config,
    'MHABconfig': MultiHeadAttentionBlockconfig,
}

ACMconfig = ACModelconfig(configurations)
# print("ACM Config")


ACMAgentI = ACMAgent(configu=ACMconfig, device="mps")
# Out:
# Using         adam_epsilon                  : 1e-07
# Using         learning_rate                 : 0.00025
# Using         clipnorm                      : 0.5
# Using         optimizer                     : <class 'torch.optim.adam.Adam'>
# Using         adam_epsilon                  : 1e-07
# Using         learning_rate                 : 0.00025
# Using         clipnorm                      : 0.5
# Using         optimizer                     : <class 'torch.optim.adam.Adam'>
# Using default save_intermediate_weights     : False
# Using default training_steps                : 10000
# Using default adam_epsilon                  : 1e-06
# Using default momentum                      : 0.9
# Using default learning_rate                 : 0.001
# Using default clipnorm                      : 0
# Using default optimizer                     : <class 'torch.optim.adam.Adam'>
# Using default weight_decay                  : 0.0
# Using         loss_function                 : None
# Using         activation                    : tanh
# Using         kernel_initializer            : orthogonal
# Using default minibatch_size                : 64
# Using default replay_buffer_size            : 5000
# Using default min_replay_buffer_size        : 64
# Using         num_minibatches               : 4
# Using default training_iterations           : 1
# Using default print_interval                : 100
# Using default noisy_sigma                   : 0.0
# Using default conv_layers                   : []
# Using default conv_layers                   : []
# Using         critic_dense_layers           : [64]
# Using         actor_dense_layers            : [64]
# Using         clip_param                    : 0.2
# Using         steps_per_epoch               : 512
# Using         replay_buffer_size            : 512
# Using         train_policy_iterations       : 4
# Using         train_value_iterations        : 4
# Using         target_kl                     : 0.02
# Using         discount_factor               : 0.99
# Using         gae_lambda                    : 0.95
# Using         entropy_coefficient           : 0.01
# Using default critic_coefficient            : 0.5
# Using default clip_low_prob                 : 0.0
# observation_dimensions:  (4,)
# num_actions:  2
# (64, 4)
# ACM Agent Configuration:
# Environment: <TimeLimit<OrderEnforcing<PassiveEnvChecker<CartPoleEnv<CartPole-v1>>>>>
# Checkpoint Path: checkpoints/ACMCartPole
# Training Steps: 100000
# Print Interval: 1000
# Steps per Epoch: 512
# Checkpoint Interval: 5000
# PPO Configuration:
# MultiHeadAttentionBlock config:
# Config: <ACMconfig.MHABconfig object at 0x324558280>
# Memory Buffer Configuration:
# Buffer Size: 1000

# %%
# %matplotlib inline

# %%
### WRITING TESTS ###
### NETWORK TESTS ###

# # Test the network's forward pass
# input = torch.randn(1, ACMAgentI.network.input_dim)
# history = torch.randn(5, ACMAgentI.network.input_dim)
# output = ACMAgentI.network.forward(input, history)
# assert output.shape == (1, ACMAgentI.network.output_dim), "Output shape mismatch"

# TESTING
# GIVEN INPUT VECTOR : 4
# HISTORY : 1, 3, 5, 7
# Target = Gaussian weighted averge of 1,3,5,7 centered aroind 4
# updateplot = 10000
# plot = []
# for i in range(10000):

#     loss = []
#     for o in range(50):
#         input = torch.randn(1,1)
#         history = torch.randn(4,1)
#         weights = torch.exp(-0.5 * ((input - history) ** 2).sum(dim=1))
#         target = torch.sum(weights * history) / torch.sum(weights)
#         output = ACMAgentI.network.forward(input, history)
#         loss.append(torch.nn.HuberLoss()(output[0], target))
        
#     print("Epoch: ", i)
#     loss = torch.mean(torch.stack(loss))
#     plot.append(loss.item())
#     ACMAgentI.network.learn(loss)

# import matplotlib.pyplot as plt
# plt.plot(plot)
# plt.xlabel("Epochs")
# plt.ylabel("Loss")
# plt.title("ACM Network Loss")
# plt.show()

### WRITING TESTS ###
### NETWORK TESTS ###

# Test the network's forward pass
input = torch.randn(1, 1)
history = torch.randn(5, 1)
output = MultiHeadAgent(input, history)
print("Input shape: ", input.shape)
print("History shape: ", history.shape)
print("Output shape: ", output.shape)
print("Output: ", output)
print("Input: ", input)
print("History: ", history)


# TESTING
# GIVEN INPUT VECTOR : 4
# HISTORY : 1, 3, 5, 7
# Target = Gaussian weighted averge of 1,3,5,7 centered aroind 4
# updateplot = 10000
plot = []
for i in range(10000):

    loss = []
    for o in range(100):
        input = torch.randn(1, 1)
        history = torch.randn(5, 1)
        weights = torch.exp(-0.5 * ((input - history) ** 2).sum(dim=1))
        target = torch.sum(weights * history) / torch.sum(weights)
        output = MultiHeadAgent(input, history)
        loss.append(torch.nn.HuberLoss()(output, target))
        
    if i % 1000 == 0:
        print("Epoch: ", i)
    loss = torch.mean(torch.stack(loss))
    plot.append(loss.item())
    MultiHeadAgent.learn(loss)

import matplotlib.pyplot as plt
plt.plot(plot)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("ACM Network Loss")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 43
#       1 ### WRITING TESTS ###
#       2 ### NETWORK TESTS ###
#       3
#    (...)
#      41
#      42 # Test the network's forward pass
# ---> 43 input = torch.randn(1, 1)
#      44 history = torch.randn(5, 1)
#      45 output = MultiHeadAgent(input, history)
#
# NameError: name 'torch' is not defined

# %%
from ppo.ppo_agent import PPOAgent
import gymnasium as gym
import torch
from agent_configs import PPOConfig, ActorConfig, CriticConfig
from ACMconfig import ACModelconfig, ACMNconfig, ACMAconfig, Buffconfig, MHABconfig
from game_configs import CartPoleConfig
from acm_agent import ACMAgent
from acm_network import MHA
env = gym.make('CartPole-v1', render_mode='rgb_array')

device = torch.device('mps')

MultiHeadAttentionBlockconfig = {
    'optimizer': "Adam",
    'learning_rate': 1e-4,
    'adam_epsilon': 1e-7,
    'clipnorm': 0.5,
    'layers': [
        {
            'type': 'MultiheadAttention',
            'num_heads': 1,
            'dropout': 0.1,
            'embed_dim': 12,
            'bias': False,
            'batch_first': True,
            'kdim': 12,
            'vdim': 12,
            'add_zero_attn': False,
            'add_bias_kv': False
        },
        {
            'type': 'Linear',
            'in_features': 12,
            'out_features': 12,
            'bias': True,
        },
        {
            'type': 'MultiheadAttention',
            'num_heads': 1,
            'dropout': 0.1,
            'embed_dim': 12,
            'bias': False,
            'batch_first': True,
            'kdim': 12,
            'vdim': 12,
            'add_zero_attn': False,
            'add_bias_kv': False
        },
        {
            'type': 'Linear',
            'in_features': 12,
            'out_features': 12,
            'bias': True,
        },
        {
            'type': 'MultiheadAttention',
            'num_heads': 1,
            'dropout': 0.1,
            'embed_dim': 4,
            'bias': False,
            'batch_first': True,
            'kdim': 12,
            'vdim': 12,
            'add_zero_attn': False,
            'add_bias_kv': False
        },
        {
            'type': 'Linear',
            'in_features': 4,
            'out_features': 4,
            'bias': True,
        }
    ],
    'self_attention': [
        True,
        False,
        True,
        False,
        False,
        False,
    ]
}

MemoryBufferConfig = {
    'buffer_size': 1000,
}
config_dict = {
        'activation': 'tanh',
        'clip_param': 0.2,
        'kernel_initializer': 'orthogonal',
        # NORMALIZATION?
        'discount_factor': 0.99,
        'gae_lambda': 0.95,
        'critic_dense_layers': [64],
        'actor_dense_layers': [64],
        # REWARD CLIPPING
        'steps_per_epoch': 512,
        'train_policy_iterations': 4,
        'train_value_iterations': 4,
        'target_kl': 0.02,
        'entropy_coefficient': 0.01,
        'num_minibatches': 1,
        'loss_function': None,
        'observation_space': env.observation_space,
    }

actor_config_dict = {
    'optimizer': torch.optim.Adam,
    'learning_rate': 2.5e-6,
    'adam_epsilon': 1e-7,
    'clipnorm': 0.5,
    'loss_function': None,
}

critic_config_dict = {
    'optimizer': torch.optim.Adam,
    'learning_rate': 2.5e-6,
    'adam_epsilon': 1e-7,
    'clipnorm': 0.5,
    'loss_function': None,
}

# print("Actor Config")
actor_config = ActorConfig(actor_config_dict)
# print("Critic Config")
critic_config = CriticConfig(critic_config_dict)

# print("PPO Config")
config = PPOConfig(config_dict, CartPoleConfig(), actor_config=actor_config, critic_config=critic_config)


# print("Memory Buffer Config (for Attention Network)")
MemoryBufferConfig = Buffconfig(MemoryBufferConfig)

MultiHeadAttentionBlockconfig = MHABconfig(config=MultiHeadAttentionBlockconfig)
MultiHeadAgent = MHA(config=MultiHeadAttentionBlockconfig, device="mps", logging=False)

Agent = PPOAgent(env=env, config=config, Buffconfig=MemoryBufferConfig, MHAconfig=MultiHeadAttentionBlockconfig, device="cpu", name="PPOWithAttention")
# Out:
# /Users/Ile-Maurice/Library/Python/3.10/lib/python/site-packages/torch/utils/_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
# Using         adam_epsilon                  : 1e-07
# Using         learning_rate                 : 2.5e-06
# Using         clipnorm                      : 0.5
# Using         optimizer                     : <class 'torch.optim.adam.Adam'>
# Using         adam_epsilon                  : 1e-07
# Using         learning_rate                 : 2.5e-06
# Using         clipnorm                      : 0.5
# Using         optimizer                     : <class 'torch.optim.adam.Adam'>
# Using default save_intermediate_weights     : False
# Using default training_steps                : 10000
# Using default adam_epsilon                  : 1e-06
# Using default momentum                      : 0.9
# Using default learning_rate                 : 0.001
# Using default clipnorm                      : 0
# Using default optimizer                     : <class 'torch.optim.adam.Adam'>
# Using default weight_decay                  : 0.0
# Using         loss_function                 : None
# Using         activation                    : tanh
# Using         kernel_initializer            : orthogonal
# Using default minibatch_size                : 64
# Using default replay_buffer_size            : 5000
# Using default min_replay_buffer_size        : 64
# Using         num_minibatches               : 1
# Using default training_iterations           : 1
# Using default print_interval                : 100
# Using default noisy_sigma                   : 0.0
# Using default conv_layers                   : []
# Using default conv_layers                   : []
# Using         critic_dense_layers           : [64]
# Using         actor_dense_layers            : [64]
# Using         clip_param                    : 0.2
# Using         steps_per_epoch               : 512
# Using         replay_buffer_size            : 512
# Using         train_policy_iterations       : 4
# Using         train_value_iterations        : 4
# Using         target_kl                     : 0.02
# Using         discount_factor               : 0.99
# Using         gae_lambda                    : 0.95
# Using         entropy_coefficient           : 0.01
# Using default critic_coefficient            : 0.5
# Using default clip_low_prob                 : 0.0
# observation_dimensions:  (4,)
# num_actions:  2
# NUM actions 2
# (1, 8)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /Users/Ile-Maurice/Desktop/rl-research-main/rl-research/experiments/actor_critic_memory folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
Agent.train()
# Out:
# Resuming training at step 1 / 10000
# Training step: 1/10000
# /Users/Ile-Maurice/Desktop/rl-research-main/rl-research/ppo/ppo_agent.py:404: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.MBuff.add(torch.from_numpy(state), torch.tensor(action), torch.tensor(reward), torch.tensor(next_state), torch.tensor(log_probability), torch.tensor(0 if (terminated or truncated) else 1))
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-0.0038, -0.4163, -0.1118,  ..., -0.2749, -0.1788, -0.5178],
#         [-0.6852, -0.5715, -0.1133,  ..., -0.2749, -0.1789, -0.5178],
#         [ 0.0731,  0.1835,  0.0431,  ..., -0.2748, -0.1785, -0.5175],
#         ...,
#         [ 0.2099,  0.0974,  0.1722,  ..., -0.2749, -0.1796, -0.5184],
#         [ 0.0178, -0.6204,  0.0024,  ..., -0.2748, -0.1786, -0.5176],
#         [ 0.0291,  0.5348, -0.0056,  ..., -0.2749, -0.1787, -0.5177]],
#        grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(-2.2624e-06)
# 37 Implimentation Details KL Divergence tensor(1.9616e-08)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-3.7649e-03, -4.1633e-01, -1.1181e-01,  ...,  6.9030e+04,
#          -8.4216e+04,  6.0938e+04],
#         [-6.8520e-01, -5.7145e-01, -1.1328e-01,  ...,  2.3012e+01,
#          -3.3232e+01,  1.7773e+01],
#         [ 7.3068e-02,  1.8348e-01,  4.3083e-02,  ...,  7.0530e+04,
#          -8.6046e+04,  6.2262e+04],
#         ...,
#         [ 2.0985e-01,  9.7405e-02,  1.7218e-01,  ...,  7.0530e+04,
#          -8.6046e+04,  6.2262e+04],
#         [ 1.7774e-02, -6.2041e-01,  2.4148e-03,  ...,  6.7363e+04,
#          -8.2182e+04,  5.9466e+04],
#         [ 2.9063e-02,  5.3478e-01, -5.5935e-03,  ...,  2.3012e+01,
#          -3.3232e+01,  1.7773e+01]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(7.2326)
# 37 Implimentation Details KL Divergence tensor(7.2323)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-3.7649e-03, -4.1633e-01, -1.1181e-01,  ...,  7.9053e+06,
#          -8.0588e+06,  7.6085e+06],
#         [-6.8520e-01, -5.7145e-01, -1.1328e-01,  ...,  5.0008e+02,
#          -5.1368e+02,  4.7881e+02],
#         [ 7.3068e-02,  1.8348e-01,  4.3083e-02,  ...,  7.7506e+06,
#          -7.9012e+06,  7.4597e+06],
#         ...,
#         [ 2.0985e-01,  9.7405e-02,  1.7218e-01,  ...,  8.0020e+06,
#          -8.1573e+06,  7.7015e+06],
#         [ 1.7774e-02, -6.2041e-01,  2.4148e-03,  ...,  7.9053e+06,
#          -8.0588e+06,  7.6085e+06],
#         [ 2.9063e-02,  5.3478e-01, -5.5935e-03,  ...,  4.6058e+02,
#          -4.7313e+02,  4.4100e+02]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(7.2326)
# 37 Implimentation Details KL Divergence tensor(7.2323)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-3.7649e-03, -4.1633e-01, -1.1181e-01,  ...,  8.1253e+07,
#          -8.0171e+07,  7.9381e+07],
#         [-6.8520e-01, -5.7145e-01, -1.1328e-01,  ...,  1.4900e+03,
#          -1.4733e+03,  1.4535e+03],
#         [ 7.3068e-02,  1.8348e-01,  4.3083e-02,  ...,  8.3597e+07,
#          -8.2484e+07,  8.1672e+07],
#         ...,
#         [ 2.0985e-01,  9.7405e-02,  1.7218e-01,  ...,  7.9886e+07,
#          -7.8823e+07,  7.8046e+07],
#         [ 1.7774e-02, -6.2041e-01,  2.4148e-03,  ...,  8.0862e+07,
#          -7.9786e+07,  7.9000e+07],
#         [ 2.9063e-02,  5.3478e-01, -5.5935e-03,  ...,  1.5290e+03,
#          -1.5119e+03,  1.4915e+03]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(6.5637)
# 37 Implimentation Details KL Divergence tensor(6.5699)
# critic loss tensor(601.9719, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(27194.1328, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(24109.5820, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(6720.5293, grad_fn=<MeanBackward0>)
# True
# score:  9.0
# score:  9.0
# score:  8.0
# score:  9.0
# Moviepy - Building video checkpoints/PPOWithAttention/step_0/videos/PPOWithAttention/0/PPOWithAttention-episode-4.mp4.
# Moviepy - Writing video checkpoints/PPOWithAttention/step_0/videos/PPOWithAttention/0/PPOWithAttention-episode-4.mp4
# Moviepy - Done !
# Moviepy - video ready checkpoints/PPOWithAttention/step_0/videos/PPOWithAttention/0/PPOWithAttention-episode-4.mp4
# score:  10.0
# {'score': [{'score': 44.0}, {'score': 25.0}, {'score': 29.0}, {'score': 18.0}, {'score': 109.0}, {'score': 46.0}, {'score': 37.0}, {'score': 129.0}, {'score': 13.0}, {'score': 33.0}, {'score': 29.0}], 'actor_loss': [tensor(1.9616e-08), tensor(7.2323), tensor(7.2323), tensor(6.5699)], 'critic_loss': [tensor(601.9719), tensor(27194.1328), tensor(24109.5820), tensor(6720.5293)], 'test_score': [{'score': 9.0, 'max_score': 10.0, 'min_score': 8.0}]}
# {'score': 475.0, 'test_score': 475.0, 'actor_loss': 0.02}
# [{'score': 44.0}, {'score': 25.0}, {'score': 29.0}, {'score': 18.0}, {'score': 109.0}, {'score': 46.0}, {'score': 37.0}, {'score': 129.0}, {'score': 13.0}, {'score': 33.0}, {'score': 29.0}]
# [{'score': 9.0, 'max_score': 10.0, 'min_score': 8.0}]
# /Users/Ile-Maurice/Desktop/rl-research-main/rl-research/packages/utils/utils/utils.py:228: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   axs[row][col].set_xlim(1, len(values))
# /Users/Ile-Maurice/Desktop/rl-research-main/rl-research/ppo/ppo_agent.py:404: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.MBuff.add(torch.from_numpy(state), torch.tensor(action), torch.tensor(reward), torch.tensor(next_state), torch.tensor(log_probability), torch.tensor(0 if (terminated or truncated) else 1))
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-2.1443e-02, -5.5325e-01, -7.4756e-03,  ..., -1.3603e+05,
#           1.1704e+05, -1.3648e+05],
#         [-3.1067e-03, -4.1113e-01,  6.4681e-03,  ..., -1.2543e+05,
#           1.0791e+05, -1.2584e+05],
#         [-5.9667e-02, -7.8768e-01,  1.7657e-02,  ..., -1.3779e+05,
#           1.1856e+05, -1.3825e+05],
#         ...,
#         [-1.0576e-01, -1.3759e+00,  7.6173e-02,  ..., -1.3603e+05,
#           1.1704e+05, -1.3648e+05],
#         [-3.9333e-02, -7.5800e-01,  5.2240e-02,  ..., -1.3426e+05,
#           1.1552e+05, -1.3470e+05],
#         [-7.8813e-02, -9.3678e-01,  9.5210e-02,  ..., -1.3249e+05,
#           1.1400e+05, -1.3293e+05]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-2.1443e-02, -5.5325e-01, -7.4756e-03,  ..., -2.5193e+05,
#           2.0453e+05, -2.5264e+05],
#         [-3.1067e-03, -4.1113e-01,  6.4681e-03,  ..., -2.5760e+05,
#           2.0913e+05, -2.5832e+05],
#         [-5.9667e-02, -7.8768e-01,  1.7657e-02,  ..., -2.5476e+05,
#           2.0683e+05, -2.5548e+05],
#         ...,
#         [-1.0576e-01, -1.3759e+00,  7.6173e-02,  ..., -2.6326e+05,
#           2.1372e+05, -2.6399e+05],
#         [-3.9333e-02, -7.5800e-01,  5.2240e-02,  ..., -2.5476e+05,
#           2.0683e+05, -2.5548e+05],
#         [-7.8813e-02, -9.3678e-01,  9.5210e-02,  ..., -2.5476e+05,
#           2.0683e+05, -2.5548e+05]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-2.1443e-02, -5.5325e-01, -7.4756e-03,  ..., -3.6011e+05,
#           2.7756e+05, -3.6099e+05],
#         [-3.1067e-03, -4.1113e-01,  6.4681e-03,  ..., -3.5312e+05,
#           2.7217e+05, -3.5398e+05],
#         [-5.9667e-02, -7.8768e-01,  1.7657e-02,  ..., -3.4613e+05,
#           2.6678e+05, -3.4697e+05],
#         ...,
#         [-1.0576e-01, -1.3759e+00,  7.6173e-02,  ..., -3.5312e+05,
#           2.7217e+05, -3.5398e+05],
#         [-3.9333e-02, -7.5800e-01,  5.2240e-02,  ..., -3.4263e+05,
#           2.6408e+05, -3.4347e+05],
#         [-7.8813e-02, -9.3678e-01,  9.5210e-02,  ..., -3.5662e+05,
#           2.7486e+05, -3.5749e+05]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-2.1443e-02, -5.5325e-01, -7.4756e-03,  ..., -4.3445e+05,
#           3.1951e+05, -4.3538e+05],
#         [-3.1067e-03, -4.1113e-01,  6.4681e-03,  ..., -4.1336e+05,
#           3.0400e+05, -4.1424e+05],
#         [-5.9667e-02, -7.8768e-01,  1.7657e-02,  ..., -4.0492e+05,
#           2.9780e+05, -4.0579e+05],
#         ...,
#         [-1.0576e-01, -1.3759e+00,  7.6173e-02,  ..., -3.9649e+05,
#           2.9159e+05, -3.9733e+05],
#         [-3.9333e-02, -7.5800e-01,  5.2240e-02,  ..., -4.0914e+05,
#           3.0090e+05, -4.1002e+05],
#         [-7.8813e-02, -9.3678e-01,  9.5210e-02,  ..., -4.2601e+05,
#           3.1331e+05, -4.2692e+05]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(91.5540, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1565.9465, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(583.7742, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(557.8957, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.1992e-01, -1.3151e+00,  8.0105e-02,  ..., -3.9598e+11,
#           2.8314e+11, -3.9721e+11],
#         [-7.5121e-03, -7.3806e-01,  8.0732e-02,  ..., -3.9697e+11,
#           2.8384e+11, -3.9821e+11],
#         [-9.8802e-02, -1.1700e+00,  1.2744e-01,  ..., -4.0537e+11,
#           2.8985e+11, -4.0664e+11],
#         ...,
#         [-4.5620e-02, -1.7357e-01, -4.1611e-02,  ..., -4.8165e+05,
#           3.3941e+05, -4.8255e+05],
#         [-1.0927e-01, -1.5802e+00,  1.9493e-01,  ..., -3.9598e+11,
#           2.8314e+11, -3.9721e+11],
#         [-5.1910e-02, -3.5941e-01,  2.3256e-02,  ..., -4.0290e+11,
#           2.8808e+11, -4.0416e+11]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.1992e-01, -1.3151e+00,  8.0105e-02,  ..., -5.7239e+11,
#           3.9562e+11, -5.7415e+11],
#         [-7.5121e-03, -7.3806e-01,  8.0732e-02,  ..., -5.7239e+11,
#           3.9562e+11, -5.7415e+11],
#         [-9.8802e-02, -1.1700e+00,  1.2744e-01,  ..., -5.8519e+11,
#           4.0447e+11, -5.8699e+11],
#         ...,
#         [-4.5620e-02, -1.7357e-01, -4.1611e-02,  ..., -5.7594e+11,
#           3.9808e+11, -5.7772e+11],
#         [-1.0927e-01, -1.5802e+00,  1.9493e-01,  ..., -5.7523e+11,
#           3.9759e+11, -5.7700e+11],
#         [-5.1910e-02, -3.5941e-01,  2.3256e-02,  ..., -5.8092e+11,
#           4.0152e+11, -5.8271e+11]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.1992e-01, -1.3151e+00,  8.0105e-02,  ..., -8.2892e+11,
#           5.5575e+11, -8.3143e+11],
#         [-7.5121e-03, -7.3806e-01,  8.0732e-02,  ..., -8.2488e+11,
#           5.5305e+11, -8.2739e+11],
#         [-9.8802e-02, -1.1700e+00,  1.2744e-01,  ..., -8.1984e+11,
#           5.4966e+11, -8.2233e+11],
#         ...,
#         [-4.5620e-02, -1.7357e-01, -4.1611e-02,  ..., -8.1682e+11,
#           5.4764e+11, -8.1930e+11],
#         [-1.0927e-01, -1.5802e+00,  1.9493e-01,  ..., -8.3698e+11,
#           5.6116e+11, -8.3953e+11],
#         [-5.1910e-02, -3.5941e-01,  2.3256e-02,  ..., -8.1682e+11,
#           5.4764e+11, -8.1930e+11]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.1992e-01, -1.3151e+00,  8.0105e-02,  ..., -1.0705e+12,
#           6.9830e+11, -1.0737e+12],
#         [-7.5121e-03, -7.3806e-01,  8.0732e-02,  ..., -1.0481e+12,
#           6.8369e+11, -1.0513e+12],
#         [-9.8802e-02, -1.1700e+00,  1.2744e-01,  ..., -1.0810e+12,
#           7.0517e+11, -1.0843e+12],
#         ...,
#         [-4.5620e-02, -1.7357e-01, -4.1611e-02,  ..., -1.0705e+12,
#           6.9830e+11, -1.0737e+12],
#         [-1.0927e-01, -1.5802e+00,  1.9493e-01,  ..., -1.0758e+12,
#           7.0173e+11, -1.0790e+12],
#         [-5.1910e-02, -3.5941e-01,  2.3256e-02,  ..., -1.0560e+12,
#           6.8885e+11, -1.0592e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(916.2802, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(40.3615, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1810.0293, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(3283.7437, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.1248e-01, -1.6064e+00,  2.0166e-01,  ..., -1.2577e+12,
#           8.0029e+11, -1.2614e+12],
#         [-1.3600e-01, -1.4080e+00,  8.3093e-02,  ..., -1.2730e+12,
#           8.1004e+11, -1.2768e+12],
#         [-2.9841e-03, -3.6407e-01,  3.6511e-02,  ..., -1.2607e+12,
#           8.0224e+11, -1.2645e+12],
#         ...,
#         [-1.6790e-02, -1.1571e+00,  4.7268e-02,  ..., -1.2791e+12,
#           8.1394e+11, -1.2829e+12],
#         [ 2.3205e-03, -4.2127e-01,  2.9865e-02,  ..., -1.2684e+12,
#           8.0711e+11, -1.2722e+12],
#         [-3.2471e-02, -1.3294e+00,  9.8002e-02,  ..., -1.2577e+12,
#           8.0029e+11, -1.2614e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.1248e-01, -1.6064e+00,  2.0166e-01,  ..., -1.5163e+12,
#           9.4341e+11, -1.5208e+12],
#         [-1.3600e-01, -1.4080e+00,  8.3093e-02,  ..., -1.4961e+12,
#           9.3084e+11, -1.5005e+12],
#         [-2.9841e-03, -3.6407e-01,  3.6511e-02,  ..., -1.5108e+12,
#           9.3998e+11, -1.5152e+12],
#         ...,
#         [-1.6790e-02, -1.1571e+00,  4.7268e-02,  ..., -1.5071e+12,
#           9.3770e+11, -1.5115e+12],
#         [ 2.3205e-03, -4.2127e-01,  2.9865e-02,  ..., -1.5108e+12,
#           9.3998e+11, -1.5152e+12],
#         [-3.2471e-02, -1.3294e+00,  9.8002e-02,  ..., -1.5604e+12,
#           9.7086e+11, -1.5650e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.1248e-01, -1.6064e+00,  2.0166e-01,  ..., -1.8380e+12,
#           1.1205e+12, -1.8433e+12],
#         [-1.3600e-01, -1.4080e+00,  8.3093e-02,  ..., -1.8683e+12,
#           1.1389e+12, -1.8737e+12],
#         [-2.9841e-03, -3.6407e-01,  3.6511e-02,  ..., -1.8799e+12,
#           1.1461e+12, -1.8854e+12],
#         ...,
#         [-1.6790e-02, -1.1571e+00,  4.7268e-02,  ..., -1.8706e+12,
#           1.1404e+12, -1.8761e+12],
#         [ 2.3205e-03, -4.2127e-01,  2.9865e-02,  ..., -1.8240e+12,
#           1.1119e+12, -1.8293e+12],
#         [-3.2471e-02, -1.3294e+00,  9.8002e-02,  ..., -1.8520e+12,
#           1.1290e+12, -1.8574e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.1248e-01, -1.6064e+00,  2.0166e-01,  ..., -1.9634e+12,
#           1.1750e+12, -1.9691e+12],
#         [-1.3600e-01, -1.4080e+00,  8.3093e-02,  ..., -1.9174e+12,
#           1.1474e+12, -1.9230e+12],
#         [-2.9841e-03, -3.6407e-01,  3.6511e-02,  ..., -1.9271e+12,
#           1.1532e+12, -1.9327e+12],
#         ...,
#         [-1.6790e-02, -1.1571e+00,  4.7268e-02,  ..., -1.9465e+12,
#           1.1648e+12, -1.9521e+12],
#         [ 2.3205e-03, -4.2127e-01,  2.9865e-02,  ..., -1.9634e+12,
#           1.1750e+12, -1.9691e+12],
#         [-3.2471e-02, -1.3294e+00,  9.8002e-02,  ..., -1.9320e+12,
#           1.1561e+12, -1.9376e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(1693.2816, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(38.4045, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(2360.3127, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(5332.5825, grad_fn=<MeanBackward0>)
# True
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-2.8105e-02, -1.0213e+00,  8.4636e-02,  ..., -2.4989e+12,
#           1.4704e+12, -2.5061e+12],
#         [-2.6832e-02, -1.4761e-01,  5.9091e-03,  ..., -2.4863e+12,
#           1.4629e+12, -2.4935e+12],
#         [ 3.4652e-02, -3.1891e-02, -2.6006e-02,  ..., -2.4737e+12,
#           1.4555e+12, -2.4808e+12],
#         ...,
#         [-1.4271e-01, -1.7061e+00,  1.4822e-01,  ..., -2.5020e+12,
#           1.4722e+12, -2.5092e+12],
#         [-2.8422e-02, -2.6543e-03,  3.0006e-02,  ..., -2.4800e+12,
#           1.4592e+12, -2.4872e+12],
#         [-1.8335e-01, -1.7829e+00,  1.7208e-01,  ..., -2.4548e+12,
#           1.4444e+12, -2.4619e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-2.8105e-02, -1.0213e+00,  8.4636e-02,  ..., -2.8335e+12,
#           1.6418e+12, -2.8416e+12],
#         [-2.6832e-02, -1.4761e-01,  5.9091e-03,  ..., -2.7775e+12,
#           1.6093e+12, -2.7855e+12],
#         [ 3.4652e-02, -3.1891e-02, -2.6006e-02,  ..., -2.8335e+12,
#           1.6418e+12, -2.8416e+12],
#         ...,
#         [-1.4271e-01, -1.7061e+00,  1.4822e-01,  ..., -2.8405e+12,
#           1.6458e+12, -2.8486e+12],
#         [-2.8422e-02, -2.6543e-03,  3.0006e-02,  ..., -2.8055e+12,
#           1.6256e+12, -2.8135e+12],
#         [-1.8335e-01, -1.7829e+00,  1.7208e-01,  ..., -2.8020e+12,
#           1.6235e+12, -2.8100e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-2.8105e-02, -1.0213e+00,  8.4636e-02,  ..., -3.1775e+12,
#           1.8155e+12, -3.1866e+12],
#         [-2.6832e-02, -1.4761e-01,  5.9091e-03,  ..., -3.2091e+12,
#           1.8335e+12, -3.2183e+12],
#         [ 3.4652e-02, -3.1891e-02, -2.6006e-02,  ..., -3.2131e+12,
#           1.8358e+12, -3.2222e+12],
#         ...,
#         [-1.4271e-01, -1.7061e+00,  1.4822e-01,  ..., -3.2921e+12,
#           1.8809e+12, -3.3015e+12],
#         [-2.8422e-02, -2.6543e-03,  3.0006e-02,  ..., -3.1893e+12,
#           1.8222e+12, -3.1984e+12],
#         [-1.8335e-01, -1.7829e+00,  1.7208e-01,  ..., -3.2447e+12,
#           1.8538e+12, -3.2539e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-2.8105e-02, -1.0213e+00,  8.4636e-02,  ..., -3.5811e+12,
#           2.0201e+12, -3.5913e+12],
#         [-2.6832e-02, -1.4761e-01,  5.9091e-03,  ..., -3.4896e+12,
#           1.9685e+12, -3.4996e+12],
#         [ 3.4652e-02, -3.1891e-02, -2.6006e-02,  ..., -3.4896e+12,
#           1.9685e+12, -3.4996e+12],
#         ...,
#         [-1.4271e-01, -1.7061e+00,  1.4822e-01,  ..., -3.5158e+12,
#           1.9832e+12, -3.5258e+12],
#         [-2.8422e-02, -2.6543e-03,  3.0006e-02,  ..., -3.4766e+12,
#           1.9611e+12, -3.4864e+12],
#         [-1.8335e-01, -1.7829e+00,  1.7208e-01,  ..., -3.5419e+12,
#           1.9980e+12, -3.5520e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(5157.3789, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(2383.3257, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(50.9475, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(2643.1689, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.8399e-02, -4.0064e-01,  1.7458e-02,  ..., -4.0832e+12,
#           2.2766e+12, -4.0947e+12],
#         [ 2.0700e-02, -6.2181e-01, -2.7801e-02,  ..., -4.0240e+12,
#           2.2436e+12, -4.0354e+12],
#         [-2.5984e-02,  4.5123e-02, -1.6666e-02,  ..., -7.1363e+05,
#           3.6517e+05, -7.1353e+05],
#         ...,
#         [ 1.3472e-02, -5.7187e-01, -3.3019e-02,  ..., -4.0684e+12,
#           2.2683e+12, -4.0799e+12],
#         [-7.2542e-02, -9.6385e-01,  4.1595e-02,  ..., -4.0684e+12,
#           2.2683e+12, -4.0799e+12],
#         [ 3.8705e-02, -1.7105e-01, -2.9799e-02,  ..., -4.0388e+12,
#           2.2518e+12, -4.0502e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.8399e-02, -4.0064e-01,  1.7458e-02,  ..., -4.0909e+12,
#           2.2567e+12, -4.1024e+12],
#         [ 2.0700e-02, -6.2181e-01, -2.7801e-02,  ..., -4.0909e+12,
#           2.2567e+12, -4.1024e+12],
#         [-2.5984e-02,  4.5123e-02, -1.6666e-02,  ..., -7.5110e+05,
#           3.7824e+05, -7.5092e+05],
#         ...,
#         [ 1.3472e-02, -5.7187e-01, -3.3019e-02,  ..., -4.1772e+12,
#           2.3043e+12, -4.1889e+12],
#         [-7.2542e-02, -9.6385e-01,  4.1595e-02,  ..., -4.0807e+12,
#           2.2511e+12, -4.0922e+12],
#         [ 3.8705e-02, -1.7105e-01, -2.9799e-02,  ..., -4.1264e+12,
#           2.2763e+12, -4.1380e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.8399e-02, -4.0064e-01,  1.7458e-02,  ..., -3.8148e+12,
#           2.0840e+12, -3.8255e+12],
#         [ 2.0700e-02, -6.2181e-01, -2.7801e-02,  ..., -3.7859e+12,
#           2.0682e+12, -3.7965e+12],
#         [-2.5984e-02,  4.5123e-02, -1.6666e-02,  ..., -7.8617e+05,
#           3.9006e+05, -7.8591e+05],
#         ...,
#         [ 1.3472e-02, -5.7187e-01, -3.3019e-02,  ..., -3.8968e+12,
#           2.1288e+12, -3.9077e+12],
#         [-7.2542e-02, -9.6385e-01,  4.1595e-02,  ..., -3.8871e+12,
#           2.1235e+12, -3.8981e+12],
#         [ 3.8705e-02, -1.7105e-01, -2.9799e-02,  ..., -3.9161e+12,
#           2.1393e+12, -3.9271e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.8399e-02, -4.0064e-01,  1.7458e-02,  ..., -4.8707e+12,
#           2.6373e+12, -4.8843e+12],
#         [ 2.0700e-02, -6.2181e-01, -2.7801e-02,  ..., -4.7334e+12,
#           2.5630e+12, -4.7466e+12],
#         [-2.5984e-02,  4.5123e-02, -1.6666e-02,  ..., -7.7118e+05,
#           3.7740e+05, -7.7085e+05],
#         ...,
#         [ 1.3472e-02, -5.7187e-01, -3.3019e-02,  ..., -4.8945e+12,
#           2.6503e+12, -4.9082e+12],
#         [-7.2542e-02, -9.6385e-01,  4.1595e-02,  ..., -4.8528e+12,
#           2.6276e+12, -4.8663e+12],
#         [ 3.8705e-02, -1.7105e-01, -2.9799e-02,  ..., -4.7931e+12,
#           2.5953e+12, -4.8065e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(6292.2910, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(7265.3047, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(4915.1562, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1331.6157, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-8.0746e-02, -1.5836e+00,  1.4017e-01,  ..., -4.4684e+12,
#           2.4000e+12, -4.4809e+12],
#         [-8.8545e-02, -1.5284e+00,  1.9374e-01,  ..., -4.3713e+12,
#           2.3478e+12, -4.3835e+12],
#         [-3.6254e-02, -6.2493e-01,  2.7618e-02,  ..., -4.3227e+12,
#           2.3217e+12, -4.3348e+12],
#         ...,
#         [-8.7928e-02, -9.7771e-01,  9.3636e-02,  ..., -4.3767e+12,
#           2.3507e+12, -4.3889e+12],
#         [-8.9870e-02, -1.0224e+00,  1.4557e-02,  ..., -4.3929e+12,
#           2.3594e+12, -4.4052e+12],
#         [-5.2766e-02, -3.9034e-01,  3.9152e-02,  ..., -4.3065e+12,
#           2.3130e+12, -4.3186e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-8.0746e-02, -1.5836e+00,  1.4017e-01,  ..., -4.7348e+12,
#           2.5243e+12, -4.7479e+12],
#         [-8.8545e-02, -1.5284e+00,  1.9374e-01,  ..., -4.5996e+12,
#           2.4523e+12, -4.6125e+12],
#         [-3.6254e-02, -6.2493e-01,  2.7618e-02,  ..., -4.7289e+12,
#           2.5212e+12, -4.7421e+12],
#         ...,
#         [-8.7928e-02, -9.7771e-01,  9.3636e-02,  ..., -4.6878e+12,
#           2.4992e+12, -4.7008e+12],
#         [-8.9870e-02, -1.0224e+00,  1.4557e-02,  ..., -4.7524e+12,
#           2.5337e+12, -4.7656e+12],
#         [-5.2766e-02, -3.9034e-01,  3.9152e-02,  ..., -4.7054e+12,
#           2.5086e+12, -4.7185e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-8.0746e-02, -1.5836e+00,  1.4017e-01,  ..., -5.0339e+12,
#           2.6657e+12, -5.0478e+12],
#         [-8.8545e-02, -1.5284e+00,  1.9374e-01,  ..., -5.1456e+12,
#           2.7248e+12, -5.1599e+12],
#         [-3.6254e-02, -6.2493e-01,  2.7618e-02,  ..., -4.9780e+12,
#           2.6361e+12, -4.9918e+12],
#         ...,
#         [-8.7928e-02, -9.7771e-01,  9.3636e-02,  ..., -4.9283e+12,
#           2.6098e+12, -4.9420e+12],
#         [-8.9870e-02, -1.0224e+00,  1.4557e-02,  ..., -5.0587e+12,
#           2.6788e+12, -5.0727e+12],
#         [-5.2766e-02, -3.9034e-01,  3.9152e-02,  ..., -5.0649e+12,
#           2.6821e+12, -5.0790e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-8.0746e-02, -1.5836e+00,  1.4017e-01,  ..., -5.2811e+12,
#           2.7794e+12, -5.2957e+12],
#         [-8.8545e-02, -1.5284e+00,  1.9374e-01,  ..., -5.2620e+12,
#           2.7694e+12, -5.2766e+12],
#         [-3.6254e-02, -6.2493e-01,  2.7618e-02,  ..., -5.1795e+12,
#           2.7260e+12, -5.1939e+12],
#         ...,
#         [-8.7928e-02, -9.7771e-01,  9.3636e-02,  ..., -5.1033e+12,
#           2.6859e+12, -5.1175e+12],
#         [-8.9870e-02, -1.0224e+00,  1.4557e-02,  ..., -5.2113e+12,
#           2.7427e+12, -5.2257e+12],
#         [-5.2766e-02, -3.9034e-01,  3.9152e-02,  ..., -5.2493e+12,
#           2.7627e+12, -5.2639e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(186.7956, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1471.9037, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1667.6052, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(555.1276, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-6.4013e-02, -6.2972e-01,  3.4047e-02,  ..., -5.4454e+12,
#           2.8498e+12, -5.4605e+12],
#         [-7.9979e-02, -1.1674e+00,  1.1741e-01,  ..., -5.4385e+12,
#           2.8462e+12, -5.4535e+12],
#         [ 1.7523e-03, -6.2674e-01,  4.5588e-02,  ..., -5.3832e+12,
#           2.8172e+12, -5.3981e+12],
#         ...,
#         [-2.1979e-02, -1.8889e-01,  2.3197e-02,  ..., -5.5352e+12,
#           2.8968e+12, -5.5505e+12],
#         [-6.0440e-02, -7.8341e-01,  7.3523e-02,  ..., -5.4938e+12,
#           2.8751e+12, -5.5090e+12],
#         [-4.0628e-02, -5.8579e-01, -7.1572e-03,  ..., -5.4868e+12,
#           2.8715e+12, -5.5020e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-6.4013e-02, -6.2972e-01,  3.4047e-02,  ..., -5.0537e+12,
#           2.6313e+12, -5.0677e+12],
#         [-7.9979e-02, -1.1674e+00,  1.1741e-01,  ..., -5.0537e+12,
#           2.6313e+12, -5.0677e+12],
#         [ 1.7523e-03, -6.2674e-01,  4.5588e-02,  ..., -5.0537e+12,
#           2.6313e+12, -5.0677e+12],
#         ...,
#         [-2.1979e-02, -1.8889e-01,  2.3197e-02,  ..., -5.0035e+12,
#           2.6051e+12, -5.0173e+12],
#         [-6.0440e-02, -7.8341e-01,  7.3523e-02,  ..., -5.0663e+12,
#           2.6378e+12, -5.0803e+12],
#         [-4.0628e-02, -5.8579e-01, -7.1572e-03,  ..., -4.8716e+12,
#           2.5365e+12, -4.8851e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-6.4013e-02, -6.2972e-01,  3.4047e-02,  ..., -5.2351e+12,
#           2.7130e+12, -5.2495e+12],
#         [-7.9979e-02, -1.1674e+00,  1.1741e-01,  ..., -5.2941e+12,
#           2.7436e+12, -5.3087e+12],
#         [ 1.7523e-03, -6.2674e-01,  4.5588e-02,  ..., -5.3007e+12,
#           2.7470e+12, -5.3153e+12],
#         ...,
#         [-2.1979e-02, -1.8889e-01,  2.3197e-02,  ..., -5.2548e+12,
#           2.7232e+12, -5.2693e+12],
#         [-6.0440e-02, -7.8341e-01,  7.3523e-02,  ..., -5.2548e+12,
#           2.7232e+12, -5.2693e+12],
#         [-4.0628e-02, -5.8579e-01, -7.1572e-03,  ..., -5.2941e+12,
#           2.7436e+12, -5.3087e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-6.4013e-02, -6.2972e-01,  3.4047e-02,  ..., -5.7263e+12,
#           2.9548e+12, -5.7420e+12],
#         [-7.9979e-02, -1.1674e+00,  1.1741e-01,  ..., -5.6706e+12,
#           2.9261e+12, -5.6862e+12],
#         [ 1.7523e-03, -6.2674e-01,  4.5588e-02,  ..., -5.7124e+12,
#           2.9476e+12, -5.7281e+12],
#         ...,
#         [-2.1979e-02, -1.8889e-01,  2.3197e-02,  ..., -5.8237e+12,
#           3.0051e+12, -5.8397e+12],
#         [-6.0440e-02, -7.8341e-01,  7.3523e-02,  ..., -5.7819e+12,
#           2.9835e+12, -5.7979e+12],
#         [-4.0628e-02, -5.8579e-01, -7.1572e-03,  ..., -5.8167e+12,
#           3.0015e+12, -5.8327e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(133.8835, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(548.6500, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(223.5145, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(145.1388, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-4.7077e-02, -9.5513e-01,  4.3150e-02,  ..., -6.4228e+12,
#           3.3013e+12, -6.4405e+12],
#         [-4.4231e-02, -1.6239e-01,  2.5774e-02,  ..., -6.5196e+12,
#           3.3511e+12, -6.5376e+12],
#         [ 6.5286e-03, -8.2538e-01,  8.4615e-02,  ..., -6.6245e+12,
#           3.4050e+12, -6.6427e+12],
#         ...,
#         [-6.5130e-02, -1.3948e+00,  1.5636e-01,  ..., -6.5116e+12,
#           3.3470e+12, -6.5295e+12],
#         [-1.6671e-03, -9.9750e-01,  1.0446e-01,  ..., -6.5196e+12,
#           3.3511e+12, -6.5376e+12],
#         [-2.6317e-02, -3.9305e-01, -1.6268e-02,  ..., -6.5277e+12,
#           3.3553e+12, -6.5457e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-4.7077e-02, -9.5513e-01,  4.3150e-02,  ..., -6.1518e+12,
#           3.1508e+12, -6.1687e+12],
#         [-4.4231e-02, -1.6239e-01,  2.5774e-02,  ..., -6.2722e+12,
#           3.2125e+12, -6.2895e+12],
#         [ 6.5286e-03, -8.2538e-01,  8.4615e-02,  ..., -6.0012e+12,
#           3.0736e+12, -6.0177e+12],
#         ...,
#         [-6.5130e-02, -1.3948e+00,  1.5636e-01,  ..., -6.1292e+12,
#           3.1392e+12, -6.1460e+12],
#         [-1.6671e-03, -9.9750e-01,  1.0446e-01,  ..., -6.1668e+12,
#           3.1585e+12, -6.1838e+12],
#         [-2.6317e-02, -3.9305e-01, -1.6268e-02,  ..., -6.1216e+12,
#           3.1353e+12, -6.1385e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-4.7077e-02, -9.5513e-01,  4.3150e-02,  ..., -6.3610e+12,
#           3.2474e+12, -6.3784e+12],
#         [-4.4231e-02, -1.6239e-01,  2.5774e-02,  ..., -6.4006e+12,
#           3.2676e+12, -6.4181e+12],
#         [ 6.5286e-03, -8.2538e-01,  8.4615e-02,  ..., -6.3610e+12,
#           3.2474e+12, -6.3784e+12],
#         ...,
#         [-6.5130e-02, -1.3948e+00,  1.5636e-01,  ..., -6.3847e+12,
#           3.2595e+12, -6.4022e+12],
#         [-1.6671e-03, -9.9750e-01,  1.0446e-01,  ..., -6.4877e+12,
#           3.3121e+12, -6.5055e+12],
#         [-2.6317e-02, -3.9305e-01, -1.6268e-02,  ..., -6.5273e+12,
#           3.3323e+12, -6.5452e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-4.7077e-02, -9.5513e-01,  4.3150e-02,  ..., -6.8392e+12,
#           3.4812e+12, -6.8579e+12],
#         [-4.4231e-02, -1.6239e-01,  2.5774e-02,  ..., -6.8560e+12,
#           3.4898e+12, -6.8748e+12],
#         [ 6.5286e-03, -8.2538e-01,  8.4615e-02,  ..., -6.7300e+12,
#           3.4256e+12, -6.7484e+12],
#         ...,
#         [-6.5130e-02, -1.3948e+00,  1.5636e-01,  ..., -6.8728e+12,
#           3.4983e+12, -6.8916e+12],
#         [-1.6671e-03, -9.9750e-01,  1.0446e-01,  ..., -6.8308e+12,
#           3.4769e+12, -6.8495e+12],
#         [-2.6317e-02, -3.9305e-01, -1.6268e-02,  ..., -6.7300e+12,
#           3.4256e+12, -6.7484e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(286.7981, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(8.7105, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(883.6476, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1562.9351, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-5.0110e-02, -3.5538e-01, -3.9935e-02,  ..., -6.2464e+12,
#           3.1709e+12, -6.2635e+12],
#         [-4.5543e-02, -1.3766e+00,  1.0121e-01,  ..., -6.1197e+12,
#           3.1066e+12, -6.1364e+12],
#         [-1.0453e-01, -1.7687e+00,  1.9036e-01,  ..., -6.0526e+12,
#           3.0725e+12, -6.0692e+12],
#         ...,
#         [-3.2657e-02, -1.6119e-01, -1.8493e-02,  ..., -6.0004e+12,
#           3.0460e+12, -6.0168e+12],
#         [-7.5047e-03, -1.7045e-02,  2.1738e-02,  ..., -6.1122e+12,
#           3.1028e+12, -6.1290e+12],
#         [-2.9191e-02, -5.4946e-01,  3.0666e-02,  ..., -6.1346e+12,
#           3.1141e+12, -6.1514e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-5.0110e-02, -3.5538e-01, -3.9935e-02,  ..., -6.3724e+12,
#           3.2269e+12, -6.3899e+12],
#         [-4.5543e-02, -1.3766e+00,  1.0121e-01,  ..., -6.4737e+12,
#           3.2782e+12, -6.4914e+12],
#         [-1.0453e-01, -1.7687e+00,  1.9036e-01,  ..., -6.3491e+12,
#           3.2151e+12, -6.3664e+12],
#         ...,
#         [-3.2657e-02, -1.6119e-01, -1.8493e-02,  ..., -6.2945e+12,
#           3.1875e+12, -6.3117e+12],
#         [-7.5047e-03, -1.7045e-02,  2.1738e-02,  ..., -6.3724e+12,
#           3.2269e+12, -6.3899e+12],
#         [-2.9191e-02, -5.4946e-01,  3.0666e-02,  ..., -6.4581e+12,
#           3.2703e+12, -6.4758e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-5.0110e-02, -3.5538e-01, -3.9935e-02,  ..., -6.5180e+12,
#           3.2933e+12, -6.5358e+12],
#         [-4.5543e-02, -1.3766e+00,  1.0121e-01,  ..., -6.5748e+12,
#           3.3220e+12, -6.5928e+12],
#         [-1.0453e-01, -1.7687e+00,  1.9036e-01,  ..., -6.6073e+12,
#           3.3384e+12, -6.6253e+12],
#         ...,
#         [-3.2657e-02, -1.6119e-01, -1.8493e-02,  ..., -6.4125e+12,
#           3.2400e+12, -6.4300e+12],
#         [-7.5047e-03, -1.7045e-02,  2.1738e-02,  ..., -6.5180e+12,
#           3.2933e+12, -6.5358e+12],
#         [-2.9191e-02, -5.4946e-01,  3.0666e-02,  ..., -6.4449e+12,
#           3.2564e+12, -6.4626e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-5.0110e-02, -3.5538e-01, -3.9935e-02,  ..., -5.8092e+12,
#           2.9291e+12, -5.8250e+12],
#         [-4.5543e-02, -1.3766e+00,  1.0121e-01,  ..., -5.9026e+12,
#           2.9763e+12, -5.9187e+12],
#         [-1.0453e-01, -1.7687e+00,  1.9036e-01,  ..., -5.8882e+12,
#           2.9690e+12, -5.9043e+12],
#         ...,
#         [-3.2657e-02, -1.6119e-01, -1.8493e-02,  ..., -5.9026e+12,
#           2.9763e+12, -5.9187e+12],
#         [-7.5047e-03, -1.7045e-02,  2.1738e-02,  ..., -5.8810e+12,
#           2.9654e+12, -5.8971e+12],
#         [-2.9191e-02, -5.4946e-01,  3.0666e-02,  ..., -5.9458e+12,
#           2.9980e+12, -5.9620e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(877.8983, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(6.9400, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1750.5833, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(3884.9841, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.4370e-01, -1.8010e+00,  1.5592e-01,  ..., -5.7716e+12,
#           2.9048e+12, -5.7873e+12],
#         [-7.9489e-02, -9.4243e-01,  2.3796e-02,  ..., -5.7164e+12,
#           2.8770e+12, -5.7320e+12],
#         [-1.1001e-01, -1.3295e+00,  1.2840e-01,  ..., -5.7302e+12,
#           2.8840e+12, -5.7458e+12],
#         ...,
#         [ 6.0878e-03, -6.1559e-01,  1.7293e-04,  ..., -5.6750e+12,
#           2.8562e+12, -5.6905e+12],
#         [-4.3179e-02, -7.6653e-01,  4.0986e-02,  ..., -5.7716e+12,
#           2.9048e+12, -5.7873e+12],
#         [-3.5785e-02, -3.5145e-01,  7.7601e-03,  ..., -5.6267e+12,
#           2.8319e+12, -5.6421e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.4370e-01, -1.8010e+00,  1.5592e-01,  ..., -6.6094e+12,
#           3.3208e+12, -6.6274e+12],
#         [-7.9489e-02, -9.4243e-01,  2.3796e-02,  ..., -6.6910e+12,
#           3.3618e+12, -6.7092e+12],
#         [-1.1001e-01, -1.3295e+00,  1.2840e-01,  ..., -6.7889e+12,
#           3.4110e+12, -6.8074e+12],
#         ...,
#         [ 6.0878e-03, -6.1559e-01,  1.7293e-04,  ..., -6.6583e+12,
#           3.3454e+12, -6.6765e+12],
#         [-4.3179e-02, -7.6653e-01,  4.0986e-02,  ..., -6.7073e+12,
#           3.3700e+12, -6.7256e+12],
#         [-3.5785e-02, -3.5145e-01,  7.7601e-03,  ..., -6.8297e+12,
#           3.4315e+12, -6.8483e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.4370e-01, -1.8010e+00,  1.5592e-01,  ..., -6.7401e+12,
#           3.3813e+12, -6.7585e+12],
#         [-7.9489e-02, -9.4243e-01,  2.3796e-02,  ..., -6.7401e+12,
#           3.3813e+12, -6.7585e+12],
#         [-1.1001e-01, -1.3295e+00,  1.2840e-01,  ..., -6.7235e+12,
#           3.3730e+12, -6.7418e+12],
#         ...,
#         [ 6.0878e-03, -6.1559e-01,  1.7293e-04,  ..., -6.6986e+12,
#           3.3605e+12, -6.7169e+12],
#         [-4.3179e-02, -7.6653e-01,  4.0986e-02,  ..., -6.6737e+12,
#           3.3480e+12, -6.6920e+12],
#         [-3.5785e-02, -3.5145e-01,  7.7601e-03,  ..., -6.8230e+12,
#           3.4229e+12, -6.8416e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.4370e-01, -1.8010e+00,  1.5592e-01,  ..., -6.4954e+12,
#           3.2540e+12, -6.5132e+12],
#         [-7.9489e-02, -9.4243e-01,  2.3796e-02,  ..., -6.5198e+12,
#           3.2662e+12, -6.5375e+12],
#         [-1.1001e-01, -1.3295e+00,  1.2840e-01,  ..., -6.4306e+12,
#           3.2215e+12, -6.4481e+12],
#         ...,
#         [ 6.0878e-03, -6.1559e-01,  1.7293e-04,  ..., -6.5198e+12,
#           3.2662e+12, -6.5375e+12],
#         [-4.3179e-02, -7.6653e-01,  4.0986e-02,  ..., -6.6414e+12,
#           3.3272e+12, -6.6595e+12],
#         [-3.5785e-02, -3.5145e-01,  7.7601e-03,  ..., -6.7306e+12,
#           3.3718e+12, -6.7490e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(3862.0281, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1878.6362, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(64.5731, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1820.6384, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.0013e-01, -1.2055e+00,  1.2240e-01,  ..., -6.3474e+12,
#           3.1758e+12, -6.3647e+12],
#         [ 2.8062e-02, -4.0230e-01,  3.1079e-02,  ..., -6.3633e+12,
#           3.1838e+12, -6.3806e+12],
#         [-1.9147e-02, -9.6534e-01,  6.4371e-02,  ..., -6.3792e+12,
#           3.1917e+12, -6.3966e+12],
#         ...,
#         [-1.0503e-01, -1.5685e+00,  1.8818e-01,  ..., -6.3633e+12,
#           3.1838e+12, -6.3806e+12],
#         [-2.6199e-02, -9.9156e-01,  7.9283e-02,  ..., -6.3553e+12,
#           3.1798e+12, -6.3727e+12],
#         [-4.6305e-02, -4.0642e-01,  1.6682e-02,  ..., -6.2600e+12,
#           3.1321e+12, -6.2771e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.0013e-01, -1.2055e+00,  1.2240e-01,  ..., -6.3627e+12,
#           3.1798e+12, -6.3801e+12],
#         [ 2.8062e-02, -4.0230e-01,  3.1079e-02,  ..., -6.1897e+12,
#           3.0933e+12, -6.2066e+12],
#         [-1.9147e-02, -9.6534e-01,  6.4371e-02,  ..., -6.2762e+12,
#           3.1366e+12, -6.2933e+12],
#         ...,
#         [-1.0503e-01, -1.5685e+00,  1.8818e-01,  ..., -6.2448e+12,
#           3.1208e+12, -6.2618e+12],
#         [-2.6199e-02, -9.9156e-01,  7.9283e-02,  ..., -6.1740e+12,
#           3.0855e+12, -6.1908e+12],
#         [-4.6305e-02, -4.0642e-01,  1.6682e-02,  ..., -6.2605e+12,
#           3.1287e+12, -6.2775e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.0013e-01, -1.2055e+00,  1.2240e-01,  ..., -6.8333e+12,
#           3.4113e+12, -6.8519e+12],
#         [ 2.8062e-02, -4.0230e-01,  3.1079e-02,  ..., -6.7662e+12,
#           3.3779e+12, -6.7846e+12],
#         [-1.9147e-02, -9.6534e-01,  6.4371e-02,  ..., -6.8081e+12,
#           3.3988e+12, -6.8267e+12],
#         ...,
#         [-1.0503e-01, -1.5685e+00,  1.8818e-01,  ..., -6.7494e+12,
#           3.3695e+12, -6.7678e+12],
#         [-2.6199e-02, -9.9156e-01,  7.9283e-02,  ..., -6.7830e+12,
#           3.3862e+12, -6.8014e+12],
#         [-4.6305e-02, -4.0642e-01,  1.6682e-02,  ..., -6.7578e+12,
#           3.3737e+12, -6.7762e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-1.0013e-01, -1.2055e+00,  1.2240e-01,  ..., -6.9779e+12,
#           3.4802e+12, -6.9969e+12],
#         [ 2.8062e-02, -4.0230e-01,  3.1079e-02,  ..., -7.0629e+12,
#           3.5226e+12, -7.0822e+12],
#         [-1.9147e-02, -9.6534e-01,  6.4371e-02,  ..., -6.8929e+12,
#           3.4378e+12, -6.9117e+12],
#         ...,
#         [-1.0503e-01, -1.5685e+00,  1.8818e-01,  ..., -6.9694e+12,
#           3.4760e+12, -6.9884e+12],
#         [-2.6199e-02, -9.9156e-01,  7.9283e-02,  ..., -7.1734e+12,
#           3.5777e+12, -7.1930e+12],
#         [-4.6305e-02, -4.0642e-01,  1.6682e-02,  ..., -7.0204e+12,
#           3.5014e+12, -7.0395e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(4828.5557, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(5638.1060, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(3798.2866, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(965.4241, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[ 3.5818e-03,  2.7990e-02, -2.5275e-02,  ..., -8.1267e+05,
#           3.4565e+05, -8.1161e+05],
#         [ 6.3757e-03, -8.2755e-01,  6.8489e-02,  ..., -7.2806e+12,
#           3.6280e+12, -7.3005e+12],
#         [-1.2131e-02, -2.2653e-01,  1.9975e-02,  ..., -7.2806e+12,
#           3.6280e+12, -7.3005e+12],
#         ...,
#         [-1.7562e-02, -1.8481e-01,  2.2422e-02,  ..., -7.2896e+12,
#           3.6325e+12, -7.3095e+12],
#         [-3.5686e-02, -1.2015e+00,  6.1152e-02,  ..., -7.2896e+12,
#           3.6325e+12, -7.3095e+12],
#         [ 2.0229e-02, -1.6274e-01, -2.5589e-02,  ..., -7.3255e+12,
#           3.6504e+12, -7.3455e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[ 3.5818e-03,  2.7990e-02, -2.5275e-02,  ..., -8.1928e+05,
#           3.4796e+05, -8.1820e+05],
#         [ 6.3757e-03, -8.2755e-01,  6.8489e-02,  ..., -7.2889e+12,
#           3.6293e+12, -7.3088e+12],
#         [-1.2131e-02, -2.2653e-01,  1.9975e-02,  ..., -7.1904e+12,
#           3.5802e+12, -7.2100e+12],
#         ...,
#         [-1.7562e-02, -1.8481e-01,  2.2422e-02,  ..., -7.2173e+12,
#           3.5936e+12, -7.2369e+12],
#         [-3.5686e-02, -1.2015e+00,  6.1152e-02,  ..., -7.2620e+12,
#           3.6159e+12, -7.2818e+12],
#         [ 2.0229e-02, -1.6274e-01, -2.5589e-02,  ..., -7.1636e+12,
#           3.5669e+12, -7.1830e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[ 3.5818e-03,  2.7990e-02, -2.5275e-02,  ..., -7.4747e+05,
#           3.1704e+05, -7.4648e+05],
#         [ 6.3757e-03, -8.2755e-01,  6.8489e-02,  ..., -7.0510e+12,
#           3.5083e+12, -7.0702e+12],
#         [-1.2131e-02, -2.2653e-01,  1.9975e-02,  ..., -7.0002e+12,
#           3.4830e+12, -7.0192e+12],
#         ...,
#         [-1.7562e-02, -1.8481e-01,  2.2422e-02,  ..., -7.0256e+12,
#           3.4956e+12, -7.0447e+12],
#         [-3.5686e-02, -1.2015e+00,  6.1152e-02,  ..., -7.1188e+12,
#           3.5420e+12, -7.1382e+12],
#         [ 2.0229e-02, -1.6274e-01, -2.5589e-02,  ..., -6.8730e+12,
#           3.4197e+12, -6.8918e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[ 3.5818e-03,  2.7990e-02, -2.5275e-02,  ..., -8.1081e+05,
#           3.4349e+05, -8.0973e+05],
#         [ 6.3757e-03, -8.2755e-01,  6.8489e-02,  ..., -6.5782e+12,
#           3.2709e+12, -6.5961e+12],
#         [-1.2131e-02, -2.2653e-01,  1.9975e-02,  ..., -6.6349e+12,
#           3.2991e+12, -6.6530e+12],
#         ...,
#         [-1.7562e-02, -1.8481e-01,  2.2422e-02,  ..., -6.6673e+12,
#           3.3152e+12, -6.6855e+12],
#         [-3.5686e-02, -1.2015e+00,  6.1152e-02,  ..., -6.7240e+12,
#           3.3434e+12, -6.7423e+12],
#         [ 2.0229e-02, -1.6274e-01, -2.5589e-02,  ..., -6.7402e+12,
#           3.3515e+12, -6.7586e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(226.8651, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1436.0671, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1603.3591, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(555.3667, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[ 1.3940e-03, -5.4894e-01,  1.1394e-02,  ..., -7.3642e+12,
#           3.6595e+12, -7.3842e+12],
#         [-1.1890e-02, -2.4192e-01, -1.4055e-02,  ..., -7.3204e+12,
#           3.6377e+12, -7.3403e+12],
#         [ 9.9413e-03, -7.9096e-01,  1.4781e-02,  ..., -7.2765e+12,
#           3.6159e+12, -7.2963e+12],
#         ...,
#         [ 1.1884e-02, -5.6770e-01,  5.7213e-02,  ..., -7.2502e+12,
#           3.6029e+12, -7.2699e+12],
#         [-4.8472e-02, -1.1359e+00,  1.2381e-01,  ..., -7.1713e+12,
#           3.5637e+12, -7.1908e+12],
#         [-4.5267e-02, -1.7047e-01,  1.7798e-02,  ..., -7.2327e+12,
#           3.5942e+12, -7.2524e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[ 1.3940e-03, -5.4894e-01,  1.1394e-02,  ..., -7.3211e+12,
#           3.6361e+12, -7.3410e+12],
#         [-1.1890e-02, -2.4192e-01, -1.4055e-02,  ..., -7.3762e+12,
#           3.6635e+12, -7.3962e+12],
#         [ 9.9413e-03, -7.9096e-01,  1.4781e-02,  ..., -7.4405e+12,
#           3.6954e+12, -7.4607e+12],
#         ...,
# ...
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[ 1.5109e-02, -6.2335e-01, -2.4036e-02,  ..., -7.6868e+12,
#           3.7975e+12, -7.7076e+12],
#         [ 3.1825e-02, -5.9685e-01,  1.0363e-02,  ..., -7.7817e+12,
#           3.8444e+12, -7.8028e+12],
#         [ 3.9232e-02, -4.0746e-01,  2.8891e-02,  ..., -7.7342e+12,
#           3.8210e+12, -7.7552e+12],
#         ...,
#         [-4.0833e-02, -5.7125e-01,  5.5650e-02,  ..., -7.6678e+12,
#           3.7881e+12, -7.6886e+12],
#         [ 3.5051e-02, -1.5869e-01, -5.1697e-03,  ..., -7.7342e+12,
#           3.8210e+12, -7.7552e+12],
#         [-2.2266e-02,  3.0486e-02, -1.5734e-02,  ..., -8.1221e+05,
#           3.3998e+05, -8.1107e+05]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[ 1.5109e-02, -6.2335e-01, -2.4036e-02,  ..., -7.6853e+12,
#           3.7968e+12, -7.7062e+12],
#         [ 3.1825e-02, -5.9685e-01,  1.0363e-02,  ..., -7.6853e+12,
#           3.7968e+12, -7.7062e+12],
#         [ 3.9232e-02, -4.0746e-01,  2.8891e-02,  ..., -7.6575e+12,
#           3.7830e+12, -7.6783e+12],
#         ...,
#         [-4.0833e-02, -5.7125e-01,  5.5650e-02,  ..., -7.6204e+12,
#           3.7647e+12, -7.6410e+12],
#         [ 3.5051e-02, -1.5869e-01, -5.1697e-03,  ..., -7.7132e+12,
#           3.8106e+12, -7.7341e+12],
#         [-2.2266e-02,  3.0486e-02, -1.5734e-02,  ..., -8.8249e+05,
#           3.6940e+05, -8.8124e+05]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[ 1.5109e-02, -6.2335e-01, -2.4036e-02,  ..., -7.5992e+12,
#           3.7542e+12, -7.6198e+12],
#         [ 3.1825e-02, -5.9685e-01,  1.0363e-02,  ..., -7.5992e+12,
#           3.7542e+12, -7.6198e+12],
#         [ 3.9232e-02, -4.0746e-01,  2.8891e-02,  ..., -7.7046e+12,
#           3.8063e+12, -7.7255e+12],
#         ...,
#         [-4.0833e-02, -5.7125e-01,  5.5650e-02,  ..., -7.5512e+12,
#           3.7306e+12, -7.5717e+12],
#         [ 3.5051e-02, -1.5869e-01, -5.1697e-03,  ..., -7.8579e+12,
#           3.8821e+12, -7.8792e+12],
#         [-2.2266e-02,  3.0486e-02, -1.5734e-02,  ..., -8.4294e+05,
#           3.5285e+05, -8.4175e+05]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(98.3310, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(453.9448, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(177.7508, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(156.2986, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-4.7573e-02, -1.4050e+00,  9.8671e-02,  ..., -8.1178e+12,
#           4.0105e+12, -8.1398e+12],
#         [-5.2725e-02, -5.8895e-01, -9.6836e-03,  ..., -8.0681e+12,
#           3.9859e+12, -8.0900e+12],
#         [-9.1098e-02, -1.3824e+00,  1.2442e-01,  ..., -8.0681e+12,
#           3.9859e+12, -8.0900e+12],
#         ...,
#         [-1.0381e-01, -1.6064e+00,  1.2131e-01,  ..., -7.9489e+12,
#           3.9270e+12, -7.9704e+12],
#         [-1.4021e-01, -1.7360e+00,  1.6118e-01,  ..., -8.0780e+12,
#           3.9908e+12, -8.1000e+12],
#         [-1.1866e-01, -1.7758e+00,  1.7129e-01,  ..., -7.9191e+12,
#           3.9123e+12, -7.9405e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-4.7573e-02, -1.4050e+00,  9.8671e-02,  ..., -7.8742e+12,
#           3.8901e+12, -7.8956e+12],
#         [-5.2725e-02, -5.8895e-01, -9.6836e-03,  ..., -7.5631e+12,
#           3.7364e+12, -7.5836e+12],
#         [-9.1098e-02, -1.3824e+00,  1.2442e-01,  ..., -7.8839e+12,
#           3.8949e+12, -7.9053e+12],
#         ...,
#         [-1.0381e-01, -1.6064e+00,  1.2131e-01,  ..., -7.9228e+12,
#           3.9141e+12, -7.9443e+12],
#         [-1.4021e-01, -1.7360e+00,  1.6118e-01,  ..., -7.8742e+12,
#           3.8901e+12, -7.8956e+12],
#         [-1.1866e-01, -1.7758e+00,  1.7129e-01,  ..., -7.7478e+12,
#           3.8277e+12, -7.7689e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-4.7573e-02, -1.4050e+00,  9.8671e-02,  ..., -7.6883e+12,
#           3.7983e+12, -7.7092e+12],
#         [-5.2725e-02, -5.8895e-01, -9.6836e-03,  ..., -7.6979e+12,
#           3.8030e+12, -7.7188e+12],
#         [-9.1098e-02, -1.3824e+00,  1.2442e-01,  ..., -7.6118e+12,
#           3.7605e+12, -7.6325e+12],
#         ...,
#         [-1.0381e-01, -1.6064e+00,  1.2131e-01,  ..., -7.7648e+12,
#           3.8361e+12, -7.7859e+12],
#         [-1.4021e-01, -1.7360e+00,  1.6118e-01,  ..., -7.6787e+12,
#           3.7936e+12, -7.6996e+12],
#         [-1.1866e-01, -1.7758e+00,  1.7129e-01,  ..., -7.7744e+12,
#           3.8408e+12, -7.7955e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-4.7573e-02, -1.4050e+00,  9.8671e-02,  ..., -8.1691e+12,
#           4.0358e+12, -8.1912e+12],
#         [-5.2725e-02, -5.8895e-01, -9.6836e-03,  ..., -8.2187e+12,
#           4.0603e+12, -8.2410e+12],
#         [-9.1098e-02, -1.3824e+00,  1.2442e-01,  ..., -8.1591e+12,
#           4.0309e+12, -8.1813e+12],
#         ...,
#         [-1.0381e-01, -1.6064e+00,  1.2131e-01,  ..., -8.1988e+12,
#           4.0505e+12, -8.2211e+12],
#         [-1.4021e-01, -1.7360e+00,  1.6118e-01,  ..., -8.2088e+12,
#           4.0554e+12, -8.2311e+12],
#         [-1.1866e-01, -1.7758e+00,  1.7129e-01,  ..., -7.9904e+12,
#           3.9475e+12, -8.0121e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(292.0879, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(11.4871, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(801.9542, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1438.9536, grad_fn=<MeanBackward0>)
# True
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-9.2049e-02, -1.5610e+00,  1.4030e-01,  ..., -7.3673e+12,
#           3.6397e+12, -7.3873e+12],
#         [-3.4506e-02, -1.1885e+00,  7.4364e-02,  ..., -7.4315e+12,
#           3.6714e+12, -7.4517e+12],
#         [-4.3553e-02, -7.7279e-01,  7.6075e-03,  ..., -7.4956e+12,
#           3.7031e+12, -7.5160e+12],
#         ...,
#         [-4.1037e-02, -1.2034e+00,  6.2911e-02,  ..., -7.3582e+12,
#           3.6352e+12, -7.3782e+12],
#         [ 1.0947e-02,  3.2155e-02, -5.4276e-03,  ..., -7.4223e+12,
#           3.6669e+12, -7.4425e+12],
#         [ 1.8133e-02, -4.2722e-01,  5.0522e-02,  ..., -7.3857e+12,
#           3.6488e+12, -7.4057e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-9.2049e-02, -1.5610e+00,  1.4030e-01,  ..., -8.2025e+12,
#           4.0523e+12, -8.2247e+12],
#         [-3.4506e-02, -1.1885e+00,  7.4364e-02,  ..., -7.9856e+12,
#           3.9451e+12, -8.0073e+12],
#         [-4.3553e-02, -7.7279e-01,  7.6075e-03,  ..., -8.1236e+12,
#           4.0133e+12, -8.1457e+12],
#         ...,
#         [-4.1037e-02, -1.2034e+00,  6.2911e-02,  ..., -8.1630e+12,
#           4.0328e+12, -8.1852e+12],
#         [ 1.0947e-02,  3.2155e-02, -5.4276e-03,  ..., -7.9461e+12,
#           3.9257e+12, -7.9677e+12],
#         [ 1.8133e-02, -4.2722e-01,  5.0522e-02,  ..., -7.9954e+12,
#           3.9500e+12, -8.0171e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-9.2049e-02, -1.5610e+00,  1.4030e-01,  ..., -8.3226e+12,
#           4.1116e+12, -8.3452e+12],
#         [-3.4506e-02, -1.1885e+00,  7.4364e-02,  ..., -8.1492e+12,
#           4.0260e+12, -8.1713e+12],
#         [-4.3553e-02, -7.7279e-01,  7.6075e-03,  ..., -8.4858e+12,
#           4.1923e+12, -8.5088e+12],
#         ...,
#         [-4.1037e-02, -1.2034e+00,  6.2911e-02,  ..., -8.3226e+12,
#           4.1116e+12, -8.3452e+12],
#         [ 1.0947e-02,  3.2155e-02, -5.4276e-03,  ..., -8.4552e+12,
#           4.1771e+12, -8.4781e+12],
#         [ 1.8133e-02, -4.2722e-01,  5.0522e-02,  ..., -8.3328e+12,
#           4.1167e+12, -8.3554e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# INPUTS SHAPE torch.Size([512, 8])
# INPUTS tensor([[-9.2049e-02, -1.5610e+00,  1.4030e-01,  ..., -7.9251e+12,
#           3.9152e+12, -7.9466e+12],
#         [-3.4506e-02, -1.1885e+00,  7.4364e-02,  ..., -8.0135e+12,
#           3.9589e+12, -8.0352e+12],
#         [-4.3553e-02, -7.7279e-01,  7.6075e-03,  ..., -7.9545e+12,
#           3.9298e+12, -7.9761e+12],
#         ...,
#         [-4.1037e-02, -1.2034e+00,  6.2911e-02,  ..., -7.6207e+12,
#           3.7648e+12, -7.6413e+12],
#         [ 1.0947e-02,  3.2155e-02, -5.4276e-03,  ..., -7.8367e+12,
#           3.8716e+12, -7.8580e+12],
#         [ 1.8133e-02, -4.2722e-01,  5.0522e-02,  ..., -7.9742e+12,
#           3.9395e+12, -7.9958e+12]], grad_fn=<CatBackward0>)
# Open AI Spinning Up KL Divergence tensor(0.)
# 37 Implimentation Details KL Divergence tensor(0.)
# critic loss tensor(799.9337, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(4.8124, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(1727.8513, grad_fn=<MeanBackward0>)
# True
# critic loss tensor(3798.2285, grad_fn=<MeanBackward0>)
# True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Agent.train()
#
# File ~/Desktop/rl-research-main/rl-research/ppo/ppo_agent.py:390, in PPOAgent.train(self)
#     388 score = 0
#     389 for timestep in range(self.config.steps_per_epoch):
# --> 390     predictions = self.predict(state, info)
#     391     action = self.select_actions(predictions).item()
#     393     next_state, reward, terminated, truncated, next_info = self.env.step(
#     394         action
#     395     )
#
# File ~/Desktop/rl-research-main/rl-research/ppo/ppo_agent.py:143, in PPOAgent.predict(self, state, info, mask_actions, env)
#     138 # print("State shape", state.shape)
#     139 # print("State:", state)
#     140 # print("MHABpreprocess shape", self.MHABpreprocess(state).shape)
#     141 # print("MHABpreprocess:", self.MHABpreprocess(state))
#     142 if self.MHAconfig is not None:
# --> 143     state_input = self.MHABpreprocess(state).unsqueeze(0)
#     144 value = self.model.critic(inputs=state_input)
#     145 # print("State input shape", state_input.shape)
#     146 # print("State input:", state_input)
#
# File ~/Desktop/rl-research-main/rl-research/ppo/ppo_agent.py:267, in PPOAgent.MHABpreprocess(self, state)
#     261     history = history.view(-1, 12)
#     262     # print("History", history)
#     263     # print("History shape", history.shape)
#     264     # print("Preprocessed state", preprocessedstate)
#     265     # print("Preprocessed state shape", preprocessedstate.shape)
# --> 267     augmented_state = self.model.MHA(preprocessedstate, history)
#     268 else:
#     269     history = torch.zeros(12).to(self.device)
#
# File ~/Library/Python/3.10/lib/python/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.10/lib/python/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/rl-research-main/rl-research/experiments/actor_critic_memory/acm_network.py:347, in MHA.forward(self, state, history)
#     345     print("CURRENT SHAPE: {}".format(x.shape))
#     346     print("LAYER: {}".format(layer))
# --> 347 attn_out, attnweights = layer(query=x.unsqueeze(0), key=x.unsqueeze(0), value=x.unsqueeze(0))
#     348 if self.logging:
#     349     print("X shape: {}".format(x.unsqueeze(0)))
#
# File ~/Library/Python/3.10/lib/python/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.10/lib/python/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Library/Python/3.10/lib/python/site-packages/torch/nn/modules/activation.py:1373, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1347     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1348         query,
#    1349         key,
#    (...)
#    1370         is_causal=is_causal,
#    1371     )
#    1372 else:
# -> 1373     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1374         query,
#    1375         key,
#    1376         value,
#    1377         self.embed_dim,
#    1378         self.num_heads,
#    1379         self.in_proj_weight,
#    1380         self.in_proj_bias,
#    1381         self.bias_k,
#    1382         self.bias_v,
#    1383         self.add_zero_attn,
#    1384         self.dropout,
#    1385         self.out_proj.weight,
#    1386         self.out_proj.bias,
#    1387         training=self.training,
#    1388         key_padding_mask=key_padding_mask,
#    1389         need_weights=need_weights,
#    1390         attn_mask=attn_mask,
#    1391         average_attn_weights=average_attn_weights,
#    1392         is_causal=is_causal,
#    1393     )
#    1394 if self.batch_first and is_batched:
#    1395     return attn_output.transpose(1, 0), attn_output_weights
#
# File ~/Library/Python/3.10/lib/python/site-packages/torch/nn/functional.py:6377, in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v, average_attn_weights, is_causal)
#    6375 attn_output_weights = softmax(attn_output_weights, dim=-1)
#    6376 if dropout_p > 0.0:
# -> 6377     attn_output_weights = dropout(attn_output_weights, p=dropout_p)
#    6379 attn_output = torch.bmm(attn_output_weights, v)
#    6381 attn_output = (
#    6382     attn_output.transpose(0, 1).contiguous().view(tgt_len * bsz, embed_dim)
#    6383 )
#
# File ~/Library/Python/3.10/lib/python/site-packages/torch/nn/functional.py:1425, in dropout(input, p, training, inplace)
#    1422 if p < 0.0 or p > 1.0:
#    1423     raise ValueError(f"dropout probability has to be between 0 and 1, but got {p}")
#    1424 return (
# -> 1425     _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#    1426 )
#
# KeyboardInterrupt:
